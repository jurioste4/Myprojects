# %%
import pandas as pd

usdata = pd.read_csv("data/us.csv")
usdata.head(100)
# Out:
#                             Economies        2013        2014        2015  \
# 0                   GDP (USD million)  16784851.0  17527258.3  18224780.3
# 1                     GDP  (% growth)         1.8         2.5         2.9
# 2                Inflation (% growth)         1.5         1.6         0.1
# 3                  Unemployment Rate          7.4         6.2         5.3
# 4             Total Population ('000)    316234.5    318622.5    321039.8
# 5              Median population Age         37.6        37.7        37.8
# 6         Number of Households ('000)    122459.0    123229.0    124587.0
# 7  Consumer Expenditure (USD million)  11015084.2  11509306.2  11975445.7
# 8               Internet Users ('000)    211614.3    218081.1    224496.5
#
#          2016        2017        2018
# 0  18715040.5  19519423.5  20580223.0
# 1         1.6         2.4         2.9
# 2         1.3         2.1         2.4
# 3         4.9         4.3         3.9
# ...
