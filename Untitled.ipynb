# %%
from twitterscraper import query_tweets
import codecs
import json
import pandas as pd

# %%
if __name__ == '__main__':
    list_of_tweets = query_tweets("Trump OR Biden", 10)

    # print the retrieved tweets to the screen:
    for tweet in query_tweets("Trump OR Biden", 10):
        print(tweet)

    with codecs.open('tweets.json', 'r', 'utf-8') as f:
        tweets = json.load(f, encoding='utf-8')

    list_tweets = [list(elem.values()) for elem in tweets]
    list_columns = list(tweets[0].keys())
    df = pd.DataFrame(list_tweets, columns=list_columns)
# Out:
# INFO: queries: ['Trump OR Biden since:2006-03-21 until:2006-11-17', 'Trump OR Biden since:2006-11-17 until:2007-07-17', 'Trump OR Biden since:2007-07-17 until:2008-03-14', 'Trump OR Biden since:2008-03-14 until:2008-11-11', 'Trump OR Biden since:2008-11-11 until:2009-07-10', 'Trump OR Biden since:2009-07-10 until:2010-03-09', 'Trump OR Biden since:2010-03-09 until:2010-11-05', 'Trump OR Biden since:2010-11-05 until:2011-07-05', 'Trump OR Biden since:2011-07-05 until:2012-03-02', 'Trump OR Biden since:2012-03-02 until:2012-10-30', 'Trump OR Biden since:2012-10-30 until:2013-06-28', 'Trump OR Biden since:2013-06-28 until:2014-02-25', 'Trump OR Biden since:2014-02-25 until:2014-10-24', 'Trump OR Biden since:2014-10-24 until:2015-06-23', 'Trump OR Biden since:2015-06-23 until:2016-02-19', 'Trump OR Biden since:2016-02-19 until:2016-10-18', 'Trump OR Biden since:2016-10-18 until:2017-06-16', 'Trump OR Biden since:2017-06-16 until:2018-02-13', 'Trump OR Biden since:2018-02-13 until:2018-10-12', 'Trump OR Biden since:2018-10-12 until:2019-06-11']
# INFO: Got 0 tweets (0 new).
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 60 tweets (20 new).
# INFO: Got 80 tweets (20 new).
# INFO: Got 100 tweets (20 new).
# INFO: Got 120 tweets (20 new).
# INFO: Got 140 tweets (20 new).
# INFO: Got 160 tweets (20 new).
# INFO: Got 180 tweets (20 new).
# INFO: Got 200 tweets (20 new).
# INFO: Got 220 tweets (20 new).
# INFO: Got 240 tweets (20 new).
# INFO: Got 260 tweets (20 new).
# INFO: Got 280 tweets (20 new).
# INFO: Got 300 tweets (20 new).
# INFO: Got 320 tweets (20 new).
# INFO: Got 340 tweets (20 new).
# INFO: Got 360 tweets (20 new).
# INFO: Got 380 tweets (20 new).
# INFO: queries: ['Trump OR Biden since:2006-03-21 until:2006-11-17', 'Trump OR Biden since:2006-11-17 until:2007-07-17', 'Trump OR Biden since:2007-07-17 until:2008-03-14', 'Trump OR Biden since:2008-03-14 until:2008-11-11', 'Trump OR Biden since:2008-11-11 until:2009-07-10', 'Trump OR Biden since:2009-07-10 until:2010-03-09', 'Trump OR Biden since:2010-03-09 until: