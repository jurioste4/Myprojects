# %%
import csv
import requests
import pandas as pd


url = "http://www.city-data.com/crime/crime-Albuquerque-New-Mexico.html"

tables = pd.read_html(url)
tables
# Out:
# [    0   1    2    3    4    5    6
#  0  AK  AL   AR   AZ   CA   CO   CT
#  1  DC  DE   FL   GA   HI   IA   ID
#  2  IL  IN   KS   KY   LA   MA   MD
#  3  ME  MI   MN   MO   MS   MT   NC
#  4  ND  NE   NH   NJ   NM   NV   NY
#  5  OH  OK   OR   PA   RI   SC   SD
#  6  TN  TX   UT   VA   VT   WA   WI
#  7  WV  WY  NaN  NaN  NaN  NaN  NaN,     0   1   2   3   4   5    6
#  0  AK  AL  AR  AZ  CA  CO   CT
#  1  DE  FL  GA  HI  IA  ID   IL
#  2  IN  KS  KY  LA  MA  ME   MI
#  3  MN  MO  MS  MT  NC  ND   NE
#  4  NH  NJ  NM  NV  NY  OH   OK
#  5  OR  PA  RI  SC  SD  TN   TX
#  6  VA  VT  WA  WI  WV  WY  NaN,     0   1   2   3   4   5    6
#  0  AK  AL  AR  AZ  CA  CO   CT
#  1  DE  FL  GA  HI  IA  ID   IL
#  2  IN  KS  KY  LA  MA  ME   MI
#  3  MN  MO  MS  MT  NC  ND   NE
#  4  NH  NJ  NM  NV  NY  OH   OK
#  5  OR  PA  RI  SC  SD  TN   TX
#  6  VA  VT  WA  WI  WV  WY  NaN,     0   1   2   3    4    5    6
#  0  AL  AZ  CA  CO   CT   DE   FL
#  1  GA  HI  IA  ID   IL   IN   KS
# ...

# %%
df = tables[7]
df.columns = ['City','Crime Rate']
df
# Out:
#             City  Crime Rate
# 0   Albuquerque:       710.3
# 1      Corrales:        32.3
# 2    Rio Rancho:       141.4
# 3    Bernalillo:       413.6
# 4  Bosque Farms:       201.9
# 5       Peralta:       157.6
# 6     Los Lunas:       484.4
# 7      Edgewood:       225.3
# 8    San Ysidro:       345.2

# %%
df2 = tables[8]
df2.head(10)
# Out:
#                                                 Type             2004  \
# 0                               Murders(per 100,000)        >>41(8.6)
# 1                                 Rapes(per 100,000)      >>235(49.1)
# 2                             Robberies(per 100,000)   >>1,238(258.4)
# 3                              Assaults(per 100,000)   >>3,206(669.2)
# 4                            Burglaries(per 100,000)    >5,243(1,094)
# 5                                Thefts(per 100,000)  >>20,469(4,273)
# 6                           Auto thefts(per 100,000)   >>3,845(802.6)
# 7                                 Arson(per 100,000)        <56(11.7)
# 8  City-Data.com crime index (higher means more c...            589.8
#
#               2005             2006             2007             2008  \
# 0       >>53(10.8)         >34(6.8)        >>47(9.2)         >38(7.2)
# 1      >>285(58.1)      >>286(57.1)      >>307(59.8)      >>370(70.1)
# ...

# %%
df3 = tables[9]
df3.columns = ['City','Crime Rate 2018']
df3
# Out:
#             City  Crime Rate
# 0   Albuquerque:       743.6
# 1  U.S. Average:       207.3

# %%
df4 = tables[10]
df4.columns = ['City','Crime Rate 2017']
df4
# Out:
#             City  Crime Rate 2017
# 0   Albuquerque:            745.4
# 1  U.S. Average:            215.2
